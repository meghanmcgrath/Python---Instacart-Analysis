# %% [markdown]
# Exercise 4.6 - Task Answers

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/meghanmcgrath/Documents/Instacart Basket Analysis/02 Data'

# %% [markdown]
# Step 3/4

# %%
# Import pickle file
df_ords_prods_combined = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Check shape of the imported data frame
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  first_order  \
# 0                   2                  8                    NaN         True
# 1                   2                  8                    NaN         True
# 2                   2                  8                    NaN         True
# 3                   2                  8                    NaN         True
# 4                   2                  8                    NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# ...

# %%
# Check shape of the imported data frame
df_ords_prods_combined.shape
# Out:
# (32434489, 13)

# %% [markdown]
# Step 5

# %%
# Import product file
df_prods = pd.read_csv(os.path.join(path, 'Prepared Data', 'products_clean_no_dups.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods.shape
# Out:
# (49672, 6)

# %% [markdown]
# Step 5/6 - merge based on shared column of 'product_id'

# %%
# Merge dataframes
df_ords_prods_merged = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Merge dataframes
# ----> 2 df_ords_prods_merged = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10487, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10468 @Substitution("")
#   10469 @Appender(_merge_doc, indents=2)
#   10470 def merge(
#    (...)
#   10483     validate: MergeValidate | None = None,
#   10484 ) -> DataFrame:
#   10485     from pandas.core.reshape.merge import merge
# > 10487     return merge(
#   10488         self,
#   10489         right,
#   10490         how=how,
#   10491         on=on,
#   10492         left_on=left_on,
#   10493         right_on=right_on,
# ...

# %% [markdown]
# Value error above is 'Cannot use name of an existing column for indicator column' - need to change the name as 'merge' column already exists

# %%
# Drop merge column
df_ords_prods_combined = df_ords_prods_combined.drop(['_merge'], axis=1)

# %%
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  first_order  \
# 0                   2                  8                    NaN         True
# 1                   2                  8                    NaN         True
# 2                   2                  8                    NaN         True
# 3                   2                  8                    NaN         True
# 4                   2                  8                    NaN         True
#
#    product_id  add_to_cart_order  reordered
# 0         196                  1          0
# 1       14084                  2          0
# ...

# %%
# Rerun merge
df_ords_prods_merged = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  \
# 0             19     5.8          1987          1987   3139998      138
# 1             19     5.8          1989          1989   1977647      138
# 2             19     5.8         11433         11433    389851      709
# 3             19     5.8         12198         12198    652770      764
# 4             19     5.8         12200         12200   1813452      764
#
#    order_number  orders_day_of_week  order_hour_of_day  days_since_last_order  \
# ...

# %%
# Drop unnecessary columns
df_ords_prods_merged = df_ords_prods_merged.drop(['Unnamed: 0_x', 'Unnamed: 0.1', 'Unnamed: 0_y'], axis=1)

# %%
df_ords_prods_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 15)

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# Step 7

# %%
# Export dataframe to pickle
df_ords_prods_merged.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged.pkl'))
