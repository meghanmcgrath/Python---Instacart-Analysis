# %% [markdown]
# Task 4.8 Answers

# %% [markdown]
# Step 1 - import the relevant libraries & ords_prods_merge dataframe

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/meghanmcgrath/Documents/Instacart Basket Analysis/02 Data'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merged_4.8.pkl'))

# %% [markdown]
# Step 2 - find aggregated mean of the “order_number” column grouped by “department_id” for entire dataframe

# %%
ords_prods_merge.groupby('product_name')

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# Step 3 - analyze the result, how do the results for the entire dataframe differ from those of the subset?

# %%
Difference?

# %% [markdown]
# Step 4 - creare a loyalty flag for existing customers using the transform() and loc() functions

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    ...  add_to_cart_order  reordered  _merge    price_range_loc  \
# ...

# %% [markdown]
# I uploaded the file I used during the exercise so the loyalty flag is already present but including the code I used:
# ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
# ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'
# ords_prods_merge['loyalty_flag'].value_counts(dropna = False)

# %% [markdown]
# Step 5 - use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer)

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# Loyal customers are spending 3 dollars less per product on average than new customers and 2 dollars less than regular customers.

# %% [markdown]
# Step 6 - create a spending flag for each user based on the average price across all their orders

# %%
ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/rd/7173k27150l51821xgq1phmm0000gn/T/ipykernel_3358/72723565.py:1: FutureWarning: The provided callable <function mean at 0x106428400> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge[['user_id', 'mean_product_price']].head(20)
# Out:
#     user_id  mean_product_price
# 0       138            6.935811
# 1       138            6.935811
# 2       709            7.930208
# 3       764            4.972414
# 4       764            4.972414
# 5       777            6.935398
# 6       825            5.957576
# 7       910            6.680000
# 8      1052            7.162500
# 9      1052            7.162500
# 10     1379            5.813636
# 11     1480            5.081633
# 12     1480            5.081633
# 13     1480            5.081633
# 14     1494            6.803797
# 15     1494            6.803797
# 16     1494            6.803797
# 17     1540            6.607122
# 18     1540            6.607122
# 19     1540            6.607122

# %%
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'mean_product_price', 'spending_flag']].head(20)
# Out:
#     user_id  mean_product_price spending_flag
# 0       138            6.935811   Low spender
# 1       138            6.935811   Low spender
# 2       709            7.930208   Low spender
# 3       764            4.972414   Low spender
# 4       764            4.972414   Low spender
# 5       777            6.935398   Low spender
# 6       825            5.957576   Low spender
# 7       910            6.680000   Low spender
# 8      1052            7.162500   Low spender
# 9      1052            7.162500   Low spender
# 10     1379            5.813636   Low spender
# 11     1480            5.081633   Low spender
# 12     1480            5.081633   Low spender
# 13     1480            5.081633   Low spender
# 14     1494            6.803797   Low spender
# 15     1494            6.803797   Low spender
# 16     1494            6.803797   Low spender
# 17     1540            6.607122   Low spender
# 18     1540            6.607122   Low spender
# ...

# %% [markdown]
# Step 7 - determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column

# %%
ords_prods_merge['median_days_btwn_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)
# Out:
# /var/folders/rd/7173k27150l51821xgq1phmm0000gn/T/ipykernel_3358/2852076900.py:1: FutureWarning: The provided callable <function median at 0x1065604a0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_btwn_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
ords_prods_merge[['user_id', 'days_since_last_order', 'median_days_btwn_orders']].head(20)
# Out:
#     user_id  days_since_last_order  median_days_btwn_orders
# 0       138                    3.0                      8.0
# 1       138                   20.0                      8.0
# 2       709                    6.0                      8.0
# 3       764                    NaN                      9.0
# 4       764                    9.0                      9.0
# 5       777                   26.0                     11.0
# 6       825                   30.0                     20.0
# 7       910                   30.0                      6.0
# 8      1052                   19.0                     10.0
# 9      1052                   15.0                     10.0
# 10     1379                    NaN                     20.0
# 11     1480                    7.0                      7.0
# 12     1480                    7.0                      7.0
# 13     1480                   12.0                      7.0
# 14     1494                    2.0                      7.0
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_btwn_orders'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_btwn_orders'] <= 20) & (ords_prods_merge['median_days_btwn_orders'] > 10), 'order_frequency'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_btwn_orders'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency'].value_counts(dropna = False)
# Out:
# order_frequency
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# nan                             5
# Name: count, dtype: int64

# %% [markdown]
# Extra step - delete columns I made when mistaking median for mean in step 7

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    ...  busiest_period_of_day  max_order      loyalty_flag  \
# ...

# %%
ords_prods_merge.drop(columns = ['mean_order_frequency', 'customer_frequency'])
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %%
ords_prods_merge_final = ords_prods_merge.drop(columns = ['mean_order_frequency', 'customer_frequency'])

# %%
# Export dataframe to pickle
ords_prods_merge_final.to_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merged_final48.pkl'))
